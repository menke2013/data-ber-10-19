# %%
import pandas as pd
import numpy as np
import requests
import json
import matplotlib
import time
import random

# %% [markdown]
# # getting the players list

# %%
url = 'https://stats.nba.com/stats/commonallplayers?IsOnlyCurrentSeason=0&LeagueID=00&Season=2019-20'

headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'),
          'referer': 'http://stats.nba.com/players/'}

# %%
allplayers1 =  requests.get(url, headers= headers)

# %%
allplayers1.json()
# Out:
# {'resource': 'commonallplayers',
#  'parameters': {'LeagueID': '00',
#   'Season': '2019-20',
#   'IsOnlyCurrentSeason': 0},
#  'resultSets': [{'name': 'CommonAllPlayers',
#    'headers': ['PERSON_ID',
#     'DISPLAY_LAST_COMMA_FIRST',
#     'DISPLAY_FIRST_LAST',
#     'ROSTERSTATUS',
#     'FROM_YEAR',
#     'TO_YEAR',
#     'PLAYERCODE',
#     'TEAM_ID',
#     'TEAM_CITY',
#     'TEAM_NAME',
#     'TEAM_ABBREVIATION',
#     'TEAM_CODE',
#     'GAMES_PLAYED_FLAG',
#     'OTHERLEAGUE_EXPERIENCE_CH'],
#    'rowSet': [[76001,
#      'Abdelnaby, Alaa',
#      'Alaa Abdelnaby',
#      0,
#      '1990',
#      '1994',
#      'HISTADD_alaa_abdelnaby',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [76002,
#      'Abdul-Aziz, Zaid',
#      'Zaid Abdul-Aziz',
#      0,
#      '1968',
#      '1977',
#      'HISTADD_zaid_abdul-aziz',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [76003,
# ...

# %%
allplayers2 = allplayers1.json()
allplayers3 = allplayers2['resultSets'].copy()
allplayers4 = allplayers3[0].copy()

# %%
headerlist = allplayers4['headers']
dfplayerlist = pd.DataFrame.from_dict(allplayers4['rowSet'])

# %%
allplayers4
# Out:
# {'name': 'CommonAllPlayers',
#  'headers': ['PERSON_ID',
#   'DISPLAY_LAST_COMMA_FIRST',
#   'DISPLAY_FIRST_LAST',
#   'ROSTERSTATUS',
#   'FROM_YEAR',
#   'TO_YEAR',
#   'PLAYERCODE',
#   'TEAM_ID',
#   'TEAM_CITY',
#   'TEAM_NAME',
#   'TEAM_ABBREVIATION',
#   'TEAM_CODE',
#   'GAMES_PLAYED_FLAG',
#   'OTHERLEAGUE_EXPERIENCE_CH'],
#  'rowSet': [[76001,
#    'Abdelnaby, Alaa',
#    'Alaa Abdelnaby',
#    0,
#    '1990',
#    '1994',
#    'HISTADD_alaa_abdelnaby',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y',
#    '00'],
#   [76002,
#    'Abdul-Aziz, Zaid',
#    'Zaid Abdul-Aziz',
#    0,
#    '1968',
#    '1977',
#    'HISTADD_zaid_abdul-aziz',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y',
#    '00'],
#   [76003,
#    'Abdul-Jabbar, Kareem',
#    'Kareem Abdul-Jabbar',
#    0,
#    '1969',
#    '1988',
#    'HISTADD_kareem_abdul-jabbar',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y',
#    '00'],
#   [51,
#    'Abdul-Rauf, Mahmoud',
#    'Mahmoud Abdul-Rauf',
# ...

# %%
dfplayerlist.columns = headerlist

# %%
dfplayerlist.head(50)
# Out:
#     PERSON_ID   DISPLAY_LAST_COMMA_FIRST        DISPLAY_FIRST_LAST  \
# 0       76001            Abdelnaby, Alaa            Alaa Abdelnaby
# 1       76002           Abdul-Aziz, Zaid           Zaid Abdul-Aziz
# 2       76003       Abdul-Jabbar, Kareem       Kareem Abdul-Jabbar
# 3          51        Abdul-Rauf, Mahmoud        Mahmoud Abdul-Rauf
# 4        1505         Abdul-Wahad, Tariq         Tariq Abdul-Wahad
# 5         949       Abdur-Rahim, Shareef       Shareef Abdur-Rahim
# 6       76005             Abernethy, Tom             Tom Abernethy
# 7       76006               Able, Forest               Forest Able
# 8       76007            Abramovic, John            John Abramovic
# 9      203518              Abrines, Alex              Alex Abrines
# 10     101165                Acker, Alex                Alex Acker
# 11      76008           Ackerman, Donald           Donald Ackerman
# 12      76009                Acres, Mark                Mark Acres
# ...

# %%
dfplayerlist.shape
# Out:
# (4489, 14)

# %%
dfplayerlist.keys()
# Out:
# Index(['PERSON_ID', 'DISPLAY_LAST_COMMA_FIRST', 'DISPLAY_FIRST_LAST',
#        'ROSTERSTATUS', 'FROM_YEAR', 'TO_YEAR', 'PLAYERCODE', 'TEAM_ID',
#        'TEAM_CITY', 'TEAM_NAME', 'TEAM_ABBREVIATION', 'TEAM_CODE',
#        'GAMES_PLAYED_FLAG', 'OTHERLEAGUE_EXPERIENCE_CH'],
#       dtype='object')

# %%
dfplayerlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4489 entries, 0 to 4488
# Data columns (total 14 columns):
# PERSON_ID                    4489 non-null int64
# DISPLAY_LAST_COMMA_FIRST     4489 non-null object
# DISPLAY_FIRST_LAST           4489 non-null object
# ROSTERSTATUS                 4489 non-null int64
# FROM_YEAR                    4489 non-null object
# TO_YEAR                      4489 non-null object
# PLAYERCODE                   4488 non-null object
# TEAM_ID                      4489 non-null int64
# TEAM_CITY                    4489 non-null object
# TEAM_NAME                    4489 non-null object
# TEAM_ABBREVIATION            4489 non-null object
# TEAM_CODE                    4489 non-null object
# GAMES_PLAYED_FLAG            4489 non-null object
# OTHERLEAGUE_EXPERIENCE_CH    4489 non-null object
# dtypes: int64(3), object(11)
# memory usage: 491.1+ KB

# %%
df_bulls1920 = dfplayerlist.loc[dfplayerlist['TEAM_NAME'] == 'Bulls'].copy()

# %%
df_bulls1920
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST  DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 118     1627853        Arcidiacono, Ryan    Ryan Arcidiacono             1
# 651     1628976      Carter Jr., Wendell  Wendell Carter Jr.             1
# 1075    1627739               Dunn, Kris           Kris Dunn             1
# 1211    1626245       Felicio, Cristiano   Cristiano Felicio             1
# 1328    1629655          Gafford, Daniel      Daniel Gafford             1
# 1657    1627885      Harrison, Shaquille  Shaquille Harrison             1
# 1878    1628990      Hutchison, Chandler  Chandler Hutchison             1
# 2242    1628436             Kornet, Luke         Luke Kornet             1
# 2283     203897             LaVine, Zach         Zach LaVine             1
# 2509    1628374         Markkanen, Lauri     Lauri Markkanen             1
# 2773    1629690             Mokoka, Adam         Adam Mokoka             1
# ...

# %%
df_bulls1920.dtypes
# Out:
# PERSON_ID                     int64
# DISPLAY_LAST_COMMA_FIRST     object
# DISPLAY_FIRST_LAST           object
# ROSTERSTATUS                  int64
# FROM_YEAR                    object
# TO_YEAR                      object
# PLAYERCODE                   object
# TEAM_ID                       int64
# TEAM_CITY                    object
# TEAM_NAME                    object
# TEAM_ABBREVIATION            object
# TEAM_CODE                    object
# GAMES_PLAYED_FLAG            object
# OTHERLEAGUE_EXPERIENCE_CH    object
# dtype: object

# %%
dfplayerlist['TEAM_NAME'].value_counts()
# Out:
#                  3987
# Nets               18
# Grizzlies          17
# Wizards            17
# Pistons            17
# 76ers              17
# Knicks             17
# Bulls              17
# Kings              17
# Bucks              17
# Spurs              17
# Raptors            17
# Lakers             17
# Jazz               17
# Pelicans           17
# Mavericks          17
# Pacers             17
# Hawks              17
# Hornets            17
# Celtics            17
# Clippers           17
# Timberwolves       17
# Thunder            16
# Rockets            16
# Suns               16
# Nuggets            16
# Warriors           16
# Magic              16
# Trail Blazers      16
# Heat               16
# Cavaliers          16
# Name: TEAM_NAME, dtype: int64

# %%
list_teams = dfplayerlist['TEAM_NAME'].unique().tolist()
list_teams.pop(0)
list_teams
# Out:
# ['Thunder',
#  'Heat',
#  'Spurs',
#  'Pelicans',
#  'Grizzlies',
#  'Nets',
#  'Knicks',
#  'Magic',
#  'Bucks',
#  'Lakers',
#  'Trail Blazers',
#  'Raptors',
#  'Bulls',
#  'Kings',
#  'Suns',
#  'Hornets',
#  'Mavericks',
#  'Nuggets',
#  'Timberwolves',
#  'Wizards',
#  'Hawks',
#  'Clippers',
#  'Pacers',
#  'Jazz',
#  '76ers',
#  'Pistons',
#  'Warriors',
#  'Celtics',
#  'Rockets',
#  'Cavaliers']

# %%
dic_team_team_id = {}

for a in list_teams:

    x = dfplayerlist.loc[dfplayerlist['TEAM_NAME'] == a ]['TEAM_ID'].unique()[0]
    dic_team_team_id[a] = x

# %%
dic_team_team_id
# Out:
# {'Thunder': 1610612760,
#  'Heat': 1610612748,
#  'Spurs': 1610612759,
#  'Pelicans': 1610612740,
#  'Grizzlies': 1610612763,
#  'Nets': 1610612751,
#  'Knicks': 1610612752,
#  'Magic': 1610612753,
#  'Bucks': 1610612749,
#  'Lakers': 1610612747,
#  'Trail Blazers': 1610612757,
#  'Raptors': 1610612761,
#  'Bulls': 1610612741,
#  'Kings': 1610612758,
#  'Suns': 1610612756,
#  'Hornets': 1610612766,
#  'Mavericks': 1610612742,
#  'Nuggets': 1610612743,
#  'Timberwolves': 1610612750,
#  'Wizards': 1610612764,
#  'Hawks': 1610612737,
#  'Clippers': 1610612746,
#  'Pacers': 1610612754,
#  'Jazz': 1610612762,
#  '76ers': 1610612755,
#  'Pistons': 1610612765,
#  'Warriors': 1610612744,
#  'Celtics': 1610612738,
#  'Rockets': 1610612745,
#  'Cavaliers': 1610612739}

# %%
dic_teamid_team = {a: b for b, a in dic_team_team_id.items()}

# %%
dic_teamid_team
# Out:
# {1610612760: 'Thunder',
#  1610612748: 'Heat',
#  1610612759: 'Spurs',
#  1610612740: 'Pelicans',
#  1610612763: 'Grizzlies',
#  1610612751: 'Nets',
#  1610612752: 'Knicks',
#  1610612753: 'Magic',
#  1610612749: 'Bucks',
#  1610612747: 'Lakers',
#  1610612757: 'Trail Blazers',
#  1610612761: 'Raptors',
#  1610612741: 'Bulls',
#  1610612758: 'Kings',
#  1610612756: 'Suns',
#  1610612766: 'Hornets',
#  1610612742: 'Mavericks',
#  1610612743: 'Nuggets',
#  1610612750: 'Timberwolves',
#  1610612764: 'Wizards',
#  1610612737: 'Hawks',
#  1610612746: 'Clippers',
#  1610612754: 'Pacers',
#  1610612762: 'Jazz',
#  1610612755: '76ers',
#  1610612765: 'Pistons',
#  1610612744: 'Warriors',
#  1610612738: 'Celtics',
#  1610612745: 'Rockets',
#  1610612739: 'Cavaliers'}

# %%
list_teamid = dic_teamid_team.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-a71b8a040de7> in <module>
# ----> 1 list_teamid = dic_teamid_team.keys().tolist()
#
# AttributeError: 'dict_keys' object has no attribute 'tolist'

# %%
for x in list_teamid:
    print (x)
# Out:
# 1610612760
# 1610612748
# 1610612759
# 1610612740
# 1610612763
# 1610612751
# 1610612752
# 1610612753
# 1610612749
# 1610612747
# 1610612757
# 1610612761
# 1610612741
# 1610612758
# 1610612756
# 1610612766
# 1610612742
# 1610612743
# 1610612750
# 1610612764
# 1610612737
# 1610612746
# 1610612754
# 1610612762
# 1610612755
# 1610612765
# 1610612744
# 1610612738
# 1610612745
# 1610612739

# %%
def get_current_team_roster(teamid,first=False):
    
    if first:
        url = f'https://stats.nba.com/stats/commonteamroster?Season=2019-20&TeamID= {teamid}'
        call1 =  requests.get(url, headers= headers).json()
        call2 = call1['resultSets'].copy()
        call3 = call2[0].copy()
        df_players_teams_func = pd.DataFrame.from_dict(call3['rowSet'])
        headerlist_func = call3['headers']
        df_players_teams_func.columns = headerlist_func
        
        return df_players_teams_func
    
    else:
        print('test')
        url = f'https://stats.nba.com/stats/commonteamroster?Season=2019-20&TeamID= {teamid}'
        call1 =  requests.get(url, headers= headers).json()
        call2 = call1['resultSets'].copy()
        call3 = call2[0].copy()
        df_players_teams_func = pd.DataFrame.from_dict(call3['rowSet'])
    
        return df_players_teams_func

# %%
id_bulls = dic_team_team_id['Bulls']
id_thunder = dic_team_team_id['Thunder']

# %%
df_players_team = pd.DataFrame()

for x in range(2):
    print (x)
    print (len(df_players_team))
    delay = random.randint(5,90)
    print (delay)
    time.sleep(delay)
    #if len(df_players_team) == 0:
    df_temp = get_current_team_roster(id_bulls, True)
    #else:
    #    df_temp = get_current_team_roster(id_thunder, False)
    
    print (df_temp)
        
    df_players_team = df_players_team.append(df_temp, ignore_index= True)
# Out:
# 0
# 0
# 22
#         TeamID SEASON LeagueID              PLAYER NUM POSITION HEIGHT WEIGHT  \
# 0   1610612741   2019       00          Coby White   0        G    6-4    195
# 1   1610612741   2019       00         Luke Kornet   2      F-C    7-2    250
# 2   1610612741   2019       00  Shaquille Harrison   3        G    6-7    190
# 3   1610612741   2019       00   Cristiano Felicio   6      F-C   6-10    270
# 4   1610612741   2019       00         Zach LaVine   8      G-F    6-6    200
# 5   1610612741   2019       00      Daniel Gafford  12      F-C   6-10    234
# 6   1610612741   2019       00  Chandler Hutchison  15      F-G    6-7    210
# 7   1610612741   2019       00         Adam Mokoka  20        G    6-5    190
# 8   1610612741   2019       00      Thaddeus Young  21        F    6-8    235
# 9   1610612741   2019       00     Otto Porter Jr.  22        F    6-8    198
# 10  1610612741   2019       00     Lauri Markkanen  24      F-C    7-0    240
# ...

# %%
df_players_team
# Out:
#         TeamID SEASON LeagueID              PLAYER NUM POSITION HEIGHT WEIGHT  \
# 0   1610612741   2019       00          Coby White   0        G    6-4    195
# 1   1610612741   2019       00         Luke Kornet   2      F-C    7-2    250
# 2   1610612741   2019       00  Shaquille Harrison   3        G    6-7    190
# 3   1610612741   2019       00   Cristiano Felicio   6      F-C   6-10    270
# 4   1610612741   2019       00         Zach LaVine   8      G-F    6-6    200
# 5   1610612741   2019       00      Daniel Gafford  12      F-C   6-10    234
# 6   1610612741   2019       00  Chandler Hutchison  15      F-G    6-7    210
# 7   1610612741   2019       00         Adam Mokoka  20        G    6-5    190
# 8   1610612741   2019       00      Thaddeus Young  21        F    6-8    235
# 9   1610612741   2019       00     Otto Porter Jr.  22        F    6-8    198
# 10  1610612741   2019       00     Lauri Markkanen  24      F-C    7-0    240
# ...

# %%
df_players_team
# Out:
#         TeamID SEASON LeagueID              PLAYER NUM POSITION HEIGHT WEIGHT  \
# 0   1610612741   2019       00          Coby White   0        G    6-4    195
# 1   1610612741   2019       00         Luke Kornet   2      F-C    7-2    250
# 2   1610612741   2019       00  Shaquille Harrison   3        G    6-7    190
# 3   1610612741   2019       00   Cristiano Felicio   6      F-C   6-10    270
# 4   1610612741   2019       00         Zach LaVine   8      G-F    6-6    200
# 5   1610612741   2019       00      Daniel Gafford  12      F-C   6-10    234
# 6   1610612741   2019       00  Chandler Hutchison  15      F-G    6-7    210
# 7   1610612741   2019       00         Adam Mokoka  20        G    6-5    190
# 8   1610612741   2019       00      Thaddeus Young  21        F    6-8    235
# 9   1610612741   2019       00     Otto Porter Jr.  22        F    6-8    198
# 10  1610612741   2019       00     Lauri Markkanen  24      F-C    7-0    240
# ...

# %%
dftest = get_current_team_roster(id_bulls, False)
# Out:
# test

# %%
dftest
# Out:
#              0     1   2                   3   4    5     6    7  \
# 0   1610612741  2019  00          Coby White   0    G   6-4  195
# 1   1610612741  2019  00         Luke Kornet   2  F-C   7-2  250
# 2   1610612741  2019  00  Shaquille Harrison   3    G   6-7  190
# 3   1610612741  2019  00   Cristiano Felicio   6  F-C  6-10  270
# 4   1610612741  2019  00         Zach LaVine   8  G-F   6-6  200
# 5   1610612741  2019  00      Daniel Gafford  12  F-C  6-10  234
# 6   1610612741  2019  00  Chandler Hutchison  15  F-G   6-7  210
# 7   1610612741  2019  00         Adam Mokoka  20    G   6-5  190
# 8   1610612741  2019  00      Thaddeus Young  21    F   6-8  235
# 9   1610612741  2019  00     Otto Porter Jr.  22    F   6-8  198
# 10  1610612741  2019  00     Lauri Markkanen  24  F-C   7-0  240
# 11  1610612741  2019  00           Max Strus  28  G-F   6-5  215
# 12  1610612741  2019  00    Tomas Satoransky  31    G   6-7  210
# ...

# %%
url = f'https://stats.nba.com/stats/commonteamroster?Season=2019-20&TeamID= {id_bulls}'

headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'),
          'referer': 'http://stats.nba.com/players/'}

# %%
bulls_test1 =  requests.get(url, headers= headers).json()

# %%
type(bulls_test1)
# Out:
# dict

# %%
bulls_test1
# Out:
# {'resource': 'commonteamroster',
#  'parameters': {'TeamID': 1610612741, 'LeagueID': None, 'Season': '2019-20'},
#  'resultSets': [{'name': 'CommonTeamRoster',
#    'headers': ['TeamID',
#     'SEASON',
#     'LeagueID',
#     'PLAYER',
#     'NUM',
#     'POSITION',
#     'HEIGHT',
#     'WEIGHT',
#     'BIRTH_DATE',
#     'AGE',
#     'EXP',
#     'SCHOOL',
#     'PLAYER_ID'],
#    'rowSet': [[1610612741,
#      '2019',
#      '00',
#      'Coby White',
#      '0',
#      'G',
#      '6-4',
#      '195',
#      'FEB 16, 2000',
#      19.0,
#      'R',
#      'North Carolina',
#      1629632],
#     [1610612741,
#      '2019',
#      '00',
#      'Luke Kornet',
#      '2',
#      'F-C',
#      '7-2',
#      '250',
#      'JUL 15, 1995',
#      24.0,
#      '2',
#      'Vanderbilt',
#      1628436],
#     [1610612741,
#      '2019',
#      '00',
#      'Shaquille Harrison',
#      '3',
#      'G',
#      '6-7',
#      '190',
#      'OCT 06, 1993',
#      26.0,
#      '2',
# ...

# %%
bulls_test3 = bulls_test1['resultSets'].copy()
bulls_test4 = bulls_test3[0].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-c3963857fdbf> in <module>
#       1 bulls_test3 = bulls_test1['resultSets'][0]
# ----> 2 bulls_test4 = bulls_test3[0].copy()
#
# KeyError: 0

# %%
headerlist2 = bulls_test4['headers']
dfbulls_2 = pd.DataFrame.from_dict(bulls_test4['rowSet'])

# %%
dfbulls_2.columns = headerlist2

# %%
dfbulls_2
# Out:
#         TeamID SEASON LeagueID              PLAYER NUM POSITION HEIGHT WEIGHT  \
# 0   1610612741   2019       00          Coby White   0        G    6-4    195
# 1   1610612741   2019       00         Luke Kornet   2      F-C    7-2    250
# 2   1610612741   2019       00  Shaquille Harrison   3        G    6-7    190
# 3   1610612741   2019       00   Cristiano Felicio   6      F-C   6-10    270
# 4   1610612741   2019       00         Zach LaVine   8      G-F    6-6    200
# 5   1610612741   2019       00      Daniel Gafford  12      F-C   6-10    234
# 6   1610612741   2019       00  Chandler Hutchison  15      F-G    6-7    210
# 7   1610612741   2019       00         Adam Mokoka  20        G    6-5    190
# 8   1610612741   2019       00      Thaddeus Young  21        F    6-8    235
# 9   1610612741   2019       00     Otto Porter Jr.  22        F    6-8    198
# 10  1610612741   2019       00     Lauri Markkanen  24      F-C    7-0    240
# ...

# %%
dfbulls_2.replace(dic_teamid_team)
# Out:
#    TeamID SEASON LeagueID              PLAYER NUM POSITION HEIGHT WEIGHT  \
# 0   Bulls   2019       00          Coby White   0        G    6-4    195
# 1   Bulls   2019       00         Luke Kornet   2      F-C    7-2    250
# 2   Bulls   2019       00  Shaquille Harrison   3        G    6-7    190
# 3   Bulls   2019       00   Cristiano Felicio   6      F-C   6-10    270
# 4   Bulls   2019       00         Zach LaVine   8      G-F    6-6    200
# 5   Bulls   2019       00      Daniel Gafford  12      F-C   6-10    234
# 6   Bulls   2019       00  Chandler Hutchison  15      F-G    6-7    210
# 7   Bulls   2019       00         Adam Mokoka  20        G    6-5    190
# 8   Bulls   2019       00      Thaddeus Young  21        F    6-8    235
# 9   Bulls   2019       00     Otto Porter Jr.  22        F    6-8    198
# 10  Bulls   2019       00     Lauri Markkanen  24      F-C    7-0    240
# 11  Bulls   2019       00           Max Strus  28      G-F    6-5    215
# ...

# %%
len(dfbulls_2)
# Out:
# 17

# %%
dftest = pd.DataFrame()

# %%
dftest
# Out:
# Empty DataFrame
# Columns: []
# Index: []
